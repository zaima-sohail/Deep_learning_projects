# %% [markdown]
# <a href="https://colab.research.google.com/github/zaima-sohail/Deep_learning_projects/blob/main/Exponentially_Weighted_Moving_Average.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("DailyDelhiClimate.csv")

# %%
df
# Out:
#             date   meantemp   humidity  wind_speed  meanpressure
# 0     2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1     2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2     2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3     2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4     2013-01-05   6.000000  86.833333    3.700000   1016.500000
# ...          ...        ...        ...         ...           ...
# 1571  2017-04-20  34.500000  27.500000    5.562500    998.625000
# 1572  2017-04-21  34.250000  39.375000    6.962500    999.875000
# 1573  2017-04-22  32.900000  40.900000    8.890000   1001.600000
# 1574  2017-04-23  32.875000  27.500000    9.962500   1002.125000
# 1575  2017-04-24  32.000000  27.142857   12.157143   1004.142857
#
# [1576 rows x 5 columns]

# %%
df=df[['date','meantemp']]
df
# Out:
#             date   meantemp
# 0     2013-01-01  10.000000
# 1     2013-01-02   7.400000
# 2     2013-01-03   7.166667
# 3     2013-01-04   8.666667
# 4     2013-01-05   6.000000
# ...          ...        ...
# 1571  2017-04-20  34.500000
# 1572  2017-04-21  34.250000
# 1573  2017-04-22  32.900000
# 1574  2017-04-23  32.875000
# 1575  2017-04-24  32.000000
#
# [1576 rows x 2 columns]

# %%
plt.scatter(df['date'],df['meantemp'],color='red')

# %%
x1=df['meantemp'].ewm(alpha=0.5).mean()

# %%
x1
# Out:
# 0       10.000000
# 1        8.266667
# 2        7.638095
# 3        8.186667
# 4        7.058065
#           ...
# 1571    33.833047
# 1572    34.041523
# 1573    33.470762
# 1574    33.172881
# 1575    32.586440
# Name: meantemp, Length: 1576, dtype: float64

# %%
df['Expoentially weighted average']=x1
df
# Out:
# /tmp/ipykernel_2504/2905785856.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Expoentially weighted average']=x1
#             date   meantemp  Expoentially weighted average
# 0     2013-01-01  10.000000                      10.000000
# 1     2013-01-02   7.400000                       8.266667
# 2     2013-01-03   7.166667                       7.638095
# 3     2013-01-04   8.666667                       8.186667
# 4     2013-01-05   6.000000                       7.058065
# ...          ...        ...                            ...
# 1571  2017-04-20  34.500000                      33.833047
# 1572  2017-04-21  34.250000                      34.041523
# 1573  2017-04-22  32.900000                      33.470762
# ...

# %%
from matplotlib import colors
plt.scatter(df['date'],df['meantemp'],color='red')
plt.plot(df['date'],x1,color='black',label='alpha=0.9')
plt.legend()
plt.show()
